# %%
import networkx as nx
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

# %%
N = 10 #no. of nodes
p = 0.4 #ocu
G = nx.erdos_renyi_graph(N, p)
A = nx.to_numpy_array(G)
pos = nx.spring_layout(G)
labels = {node: str(node) for node in G.nodes()}

# %%
from bp_error.perc_func import perc_message_passing
from bp_error.perc_func import initialize_messages
from bp_error.perc_func import declare_vector, perc_log_meesage_pass, update_v_and_messages

# %%
messages = {}
B = {}
V = []

# %%
for i in range(N):
    for j in range(N):
        temp_list = [0 for i in range(90)]
        for k in range(N):
            if A[j][k] == 1 and k != i:
                temp_list[j*10 + k] = 1
        if j != i:
            B[f'{i},{j}'] = temp_list
            messages[f'{i},{j}'] = 0.5
    
V = declare_vector(p, N)


#for keys, values in B.items():
    #print(keys, values)

# %%
for i in range(10):
    print(len(messages))
    messages_new = {}
    messages_new = perc_log_meesage_pass(A, B, V, messages)
    messages = {}
    V_new = update_v_and_messages(p, messages_new)
    V = []
    V = V_new
    messages = messages_new
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# 90
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 for i in range(10):
#       2     print(len(messages))
#       3     messages_new = {}
# ----> 4     messages_new = perc_log_meesage_pass(A, B, V, messages)
#       5     messages = {}
#       6     V_new = update_v_and_messages(p, messages_new)
#       7     V = []
#
# File ~/belief-propagation-error/src/bp_error/perc_func.py:38, in perc_log_meesage_pass(A, B, V, messages)
#      36 i, j = keys.split(',')
#      37 temp_B = jnp.array(B[f'{i},{j}'])
# ---> 38 mu_i_j = math.exp(jnp.dot(temp_B, jnp.array(V)))
#      39 if A[i][j] != 0:
#      40     messages[f'{i},{j}'] = mu_i_j
#
#     [... skipping hidden 5 frame]
#
# File ~/belief-propagation-error/.venv/lib/python3.12/site-packages/jax/_src/numpy/tensor_contractions.py:122, in dot(a, b, precision, preferred_element_type, out_sharding)
#     120   else:
#     121     contract_dims = ((a_ndim - 1,), (b_ndim - 2,))
# --> 122 result = lax.dot_general(a, b, dimension_numbers=(contract_dims, batch_dims),
#     123                          precision=precision,
#     124                          preferred_element_type=preferred_element_type,
#     125                          out_sharding=out_sharding)
#     126 return lax._convert_element_type(result, preferred_element_type,
#     127                                  output_weak_type)
#
#     [... skipping hidden 10 frame]
#
# File ~/belief-propagation-error/.venv/lib/python3.12/site-packages/jax/_src/lax/lax.py:5570, in _dot_general_shape_rule(lhs, rhs, dimension_numbers, precision, preferred_element_type, out_sharding)
#    5567 if not core.definitely_equal_shape(lhs_contracting_shape, rhs_contracting_shape):
#    5568   msg = ("dot_general requires contracting dimensions to have the same "
#    5569          "shape, got {} and {}.")
# -> 5570   raise TypeError(msg.format(lhs_contracting_shape, rhs_contracting_shape))
#    5572 return _dot_general_shape_computation(lhs.shape, rhs.shape, dimension_numbers)
#
# TypeError: dot_general requires contracting dimensions to have the same shape, got (20,) and (90,).
